# %%
def greet():
    print("Let's get started ")

greet()
# Out:
# Let's get started

# %%
def greet(name):
    return f"Hello" + name
greeting =(greet(" Alex"))
greet("Sophia")
print(greeting)
# Out:
# Hello Alex

# %%
def add(a,b):
    return a + b
result = add(5,10)
print(result)
print(add(result, 20))
# Out:
# 15
# 35

# %%
def demo(name,age):
    return f"{name},{age}"
print(demo("Om","21"))
# Out:
# Om,21
